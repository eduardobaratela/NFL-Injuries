# %% [markdown]
# # NFL Injuries Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plays = pd.read_csv("PlayList.csv")
plays.head()
# Out:
#    PlayerKey   GameID    PlayKey RosterPosition  PlayerDay  PlayerGame  \
# 0      26624  26624-1  26624-1-1    Quarterback          1           1
# 1      26624  26624-1  26624-1-2    Quarterback          1           1
# 2      26624  26624-1  26624-1-3    Quarterback          1           1
# 3      26624  26624-1  26624-1-4    Quarterback          1           1
# 4      26624  26624-1  26624-1-5    Quarterback          1           1
#
#   StadiumType  FieldType  Temperature         Weather PlayType  \
# 0     Outdoor  Synthetic           63  Clear and warm     Pass
# 1     Outdoor  Synthetic           63  Clear and warm     Pass
# 2     Outdoor  Synthetic           63  Clear and warm     Rush
# 3     Outdoor  Synthetic           63  Clear and warm     Rush
# 4     Outdoor  Synthetic           63  Clear and warm     Pass
#
#    PlayerGamePlay Position PositionGroup
# 0               1       QB            QB
# 1               2       QB            QB
# 2               3       QB            QB
# 3               4       QB            QB
# 4               5       QB            QB

# %%
plays.isna().sum()
# Out:
# PlayerKey             0
# GameID                0
# PlayKey               0
# RosterPosition        0
# PlayerDay             0
# PlayerGame            0
# StadiumType       16910
# FieldType             0
# Temperature           0
# Weather           18691
# PlayType            367
# PlayerGamePlay        0
# Position              0
# PositionGroup         0
# dtype: int64

# %%
players = pd.read_csv("PlayerTrackData.csv")
players.head()

# %%
inj = pd.read_csv("InjuryRecord.csv")
inj

# %%
label = plays["PlayType"].value_counts().keys()
fig, ax = plt.subplots(figsize=(12, 5))
plt.bar(label, plays["PlayType"].value_counts())
plt.xticks(label, fontsize=8, rotation=30)
plt.title("PlayType", fontsize=20)
for rect in ax.patches:
        # Get X and Y placement of label from rect.
        y_value = rect.get_height()
        x_value = rect.get_x() + rect.get_width() / 2
        ax.annotate(y_value, (x_value, y_value),xytext=(0, 3), textcoords="offset points", ha='center')
      
plt.show()

# %%
label2 = inj.BodyPart.value_counts().keys()
fig2, ax2 = plt.subplots(figsize=(10, 7))
plt.pie(inj["BodyPart"].value_counts().values, labels=label2, autopct='%.2f%%')
plt.title("BodyPart", fontsize=20)
plt.show()

# %%
df_merged = pd.merge(inj, plays, on=['PlayerKey', 'GameID', 'PlayKey'], how='left')
df_merged = df_merged.drop(['RosterPosition', 'Surface'], axis = 1)

#--- Cleaning 'StadiumType' ---
df_merged["StadiumType"] = df_merged["StadiumType"].str.replace('Outdoors|Outddors|Oudoor|Open|Retr. Roof - Open|Indoor, Open Roof|Retractable Roof', 'Outdoor')
df_merged["StadiumType"] = df_merged["StadiumType"].str.replace('Indoors|Dome|Indoor, Roof Closed|Retr. Roof - Closed|Domed, closed|Closed Dome|Retr. Roof-Closed|Indoord, closed', 'Indoor')

#--- Weather' ---
#df_merged["Weather"] = df_merged["Weather"].str.replace('', 'Sunny')
# 29        63.0         9.0     Outdoor  Synthetic         42.0
# ..         ...         ...         ...        ...          ...
# 75       389.0        15.0     Outdoor    Natural         79.0
# 76       428.0        20.0     Outdoor  Synthetic         39.0
# 77       445.0        28.0      Indoor  Synthetic         70.0
# 78       471.0        29.0     Outdoor    Natural         58.0
# 79       462.0        17.0     Outdoor  Synthetic         39.0
# 80       422.0        16.0      Indoor  Synthetic         74.0
# 81        89.0        13.0     Outdoor    Natural         44.0
# 82       373.0        18.0     Outdoor    Natural         79.0
# 83       393.0        19.0     Outdoor    Natural         79.0
# 84        22.0         4.0     Outdoor    Natural         71.0
# 85       365.0         8.0     Outdoor    Natural         81.0
# 86        74.0        10.0      Indoor  Synthetic         68.0
# 87        74.0        10.0      Indoor  Synthetic         68.0
# 88       365.0         8.0     Outdoor  Synthetic         62.0
# 89       334.0         5.0     Outdoor    Natural         75.0
# 90       442.0        19.0      Indoor  Synthetic         57.0
# 91       393.0        18.0     Outdoor  Synthetic         45.0
# 92       327.0         9.0     Outdoor    Natural         81.0
# 93       379.0        14.0     Outdoor  Synthetic         78.0
# 94        58.0         8.0      Indoor  Synthetic         74.0
# 95         NaN         NaN         NaN        NaN          NaN
# 96         NaN         NaN         NaN        NaN          NaN
# 97         NaN         NaN         NaN        NaN          NaN
# 98         NaN         NaN         NaN        NaN          NaN
# 99         NaN         NaN         NaN        NaN          NaN
# 100        NaN         NaN         NaN        NaN          NaN
# 101        NaN         NaN         NaN        NaN          NaN
# 102        NaN         NaN         NaN        NaN          NaN
# 103        NaN         NaN         NaN        NaN          NaN
# 104        NaN         NaN         NaN        NaN          NaN
#
#                 Weather              PlayType  PlayerGamePlay Position  \
# 0                Cloudy                  Punt            32.0      OLB
# 1         Partly Cloudy                  Punt            26.0      OLB
# 2        Clear and warm                  Pass            70.0       SS
# 3                Cloudy                  Punt            30.0       LB
# 4         Partly Cloudy               Kickoff            69.0       WR
# 5                 Sunny                  Pass            60.0       SS
# 6                 Sunny                  Rush            22.0       RB
# 7                Cloudy                  Rush            52.0      OLB
# 8                Indoor                  Rush            61.0      ILB
# 9                 Clear                  Pass            40.0       WR
# 10                Sunny                  Pass            44.0       SS
# 11                  NaN                  Rush            58.0        T
# 12                Sunny                  Rush            23.0       RB
# 13               Cloudy                  Pass            49.0        C
# 14                Sunny                  Pass            55.0       SS
# 15               Indoor               Kickoff             8.0      OLB
# 16               Indoor                  Pass            38.0       WR
# 17               Cloudy               Kickoff            13.0       WR
# 18                Sunny                  Punt            16.0      OLB
# 19               Cloudy               Kickoff            23.0       WR
# 20               Indoor                  Rush            27.0       RB
# 21   Controlled Climate                  Pass            42.0       FS
# 22                 Cold                  Pass            31.0       DE
# 23        Partly Cloudy                  Pass            32.0      OLB
# 24        Partly Cloudy                  Pass            41.0      MLB
# 25                  NaN                  Pass            12.0       RB
# 26               Indoor                  Pass            25.0       CB
# 27        Partly Cloudy               Kickoff             9.0       WR
# 28                Sunny                  Rush            12.0      OLB
# 29               Cloudy                  Rush             9.0      OLB
# ..                  ...                   ...             ...      ...
# 75                Clear                  Pass            35.0        T
# 76         Mostly Sunny                  Rush            21.0       DT
# 77          Clear Skies                  Pass            35.0       WR
# 78                 Rain         Punt Returned            14.0       WR
# 79          Rain shower                  Rush            27.0       WR
# 80          Clear skies                  Pass            19.0      ILB
# 81                Clear                  Pass            20.0       WR
# 82                Clear                  Rush            21.0        C
# 83        Partly Cloudy                  Rush             7.0       FS
# 84        Partly Cloudy                  Pass            16.0       WR
# 85        Partly Cloudy                  Pass            15.0       TE
# 86              Indoors                  Pass            18.0       CB
# 87              Indoors                  Pass            18.0       CB
# 88      Cloudy and Cool                  Rush             9.0       DT
# 89                Clear                  Rush             4.0       DE
# 90        Mostly cloudy                  Rush            15.0        C
# 91               Cloudy      Kickoff Returned             3.0       TE
# 92               Cloudy                  Rush             4.0       WR
# 93        Partly Cloudy                  Pass             3.0       WR
# 94          Clear skies  Kickoff Not Returned             1.0       DB
# 95                  NaN                   NaN             NaN      NaN
# 96                  NaN                   NaN             NaN      NaN
# 97                  NaN                   NaN             NaN      NaN
# 98                  NaN                   NaN             NaN      NaN
# 99                  NaN                   NaN             NaN      NaN
# 100                 NaN                   NaN             NaN      NaN
# 101                 NaN                   NaN             NaN      NaN
# 102                 NaN                   NaN             NaN      NaN
# 103                 NaN                   NaN             NaN      NaN
# 104                 NaN                   NaN             NaN      NaN
#
#     PositionGroup
# 0              LB
# 1              LB
# 2              DB
# 3              LB
# 4              WR
# 5              DB
# 6              RB
# 7              LB
# 8              LB
# 9              WR
# 10             DB
# 11             OL
# 12             RB
# 13             OL
# 14             DB
# 15             LB
# 16             WR
# 17             WR
# 18             LB
# 19             WR
# 20             RB
# 21             DB
# 22             DL
# 23             LB
# 24             LB
# 25             RB
# 26             DB
# 27             WR
# 28             LB
# 29             LB
# ..            ...
# 75             OL
# 76             DL
# 77             WR
# 78             WR
# 79             WR
# 80             LB
# 81             WR
# 82             OL
# 83             DB
# 84             WR
# 85             TE
# 86             DB
# 87             DB
# 88             DL
# 89             DL
# 90             OL
# 91             TE
# 92             WR
# 93             WR
# 94             DB
# 95            NaN
# 96            NaN
# 97            NaN
# 98            NaN
# 99            NaN
# 100           NaN
# 101           NaN
# 102           NaN
# 103           NaN
# 104           NaN
#
# [105 rows x 18 columns]

# %%
df_merged["Weather"].value_counts().sum()
# Out:
# 74

# %%
knee_df = df_merged[df_merged['BodyPart'] == 'Knee']
knee_df['PositionGroup'].isna().sum()
# Out:
# 12

# %%
plays.PlayKey.nunique()
# Out:
# 267005

# %%
# Out:
# 102
